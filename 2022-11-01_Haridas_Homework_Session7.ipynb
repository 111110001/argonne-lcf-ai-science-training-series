# %% [markdown]
# # <center> Assignment  – Running Large-scale Training on a Supercomputer (11/1/22)
# # <center> Submitted By: Haridas Das

# %% [markdown]
# # Homework
#
# Any sort of proof that you were able to run it successfully will suffice
# From a thread in 07_large_scale_training.

# %% [markdown]
# # Solution

# %% [markdown]
# I tried many ways, though. All my attempts failed. I hope it would be easy, but it seems not. I was trying to run src/ai4sci/main.sh, but I got the following error.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sorry for incomplete work.
